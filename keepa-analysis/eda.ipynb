# %%
from linearmodels.iv import IV2SLS
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# Create some summary statistics plots of the sales ranks
